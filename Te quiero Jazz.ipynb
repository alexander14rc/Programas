# %% [markdown]
# Hola, no se por que esta canción me recuerda a ti **Jazz** :-)
#
#    **TE QUIERO JAZZ **
#
# Lo puedo escribir 10 veces:

# %%
tq = 'Te quiero Jazz'
for ii in range(11):
    print(tq)
# Out:
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz
# Te quiero Jazz

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("IvPT2QuCIOA")

# %% [markdown]
# Lo puedo escribir 1000 veces tambien si **1000..!!! veces**

# %%
tq = 'Te quiero Jazz'
for ii in range(1001):
    print(tq,"Mucho.. deveritas deveritas!")
# Out:
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# Te quiero Jazz Mucho.. deveritas deveritas!
# ...
